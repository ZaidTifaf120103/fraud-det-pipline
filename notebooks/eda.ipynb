# %%
#Basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


#Sampling methods
from imblearn.under_sampling import RandomUnderSampler

#feature engineering
import datetime as dt
import category_encoders as ce


#Feature Selection
from boruta import BorutaPy

#Models
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_csv(r"C:\Users\zaid2\Desktop\fraud-det-pipline\data\raw\fraudTrain.csv", index_col=0)

# %%
train.head(3)
# Out:
#   trans_date_trans_time            cc_num                         merchant  \
# 0   2019-01-01 00:00:18  2703186189652095       fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322  fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661             fraud_Lind-Buckridge
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
#
#                          street            city state    zip      lat  \
# 0                561 Perry Cove  Moravian Falls    NC  28654  36.0788
# 1  43039 Riley Greens Suite 393          Orient    WA  99160  48.8878
# 2      594 White Dale Suite 530      Malad City    ID  83252  42.1808
#
#        long  city_pop                                job         dob  \
# 0  -81.1781      3495          Psychologist, counselling  1988-03-09
# 1 -118.2105       149  Special educational needs teacher  1978-06-21
# 2 -112.2620      4154        Nature conservation officer  1962-01-19
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
# 2  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704 -112.154481
#
#    is_fraud
# 0         0
# 1         0
# 2         0

# %%
print("\nNombre de valeurs manquantes par colonne :")
print(train.isnull().sum())
# Out:
# Nombre de valeurs manquantes par colonne :
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
print("\nNombre de valeurs dupliquer :")
print(train.duplicated().sum())
# Out:
# Nombre de valeurs dupliquer :
# 0

# %%
print("\nDistribution des transactions frauduleuses :")
print(train['is_fraud'].value_counts())
plt.figure(figsize=(6, 4))
sns.countplot(x='is_fraud', data=train)
plt.title('Distribution des transactions frauduleuses')
plt.show()
# Out:
# Distribution des transactions frauduleuses :
# is_fraud
# 0    1289169
# 1       7506
# Name: count, dtype: int64

# %%
#The Age distribution behavior for fraud and non-fraud transactions.
train['age'] = dt.date.today().year-pd.to_datetime(train['dob']).dt.year
ax = sns.kdeplot(x='age', data=train, hue='is_fraud', common_norm=False)
ax.set_xlabel('Credit Card Holder Age')
ax.set_ylabel('Density')
plt.xticks(np.arange(0, 110, 10))
plt.title('Age Distribution')
plt.legend(title='Type', labels=['Fraud', 'Not Fraud'])
# Out:
# c:\Users\zaid2\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\zaid2\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
#Does the time in a day has any impact
train['hour'] = pd.to_datetime(train['trans_date_trans_time']).dt.hour
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6), sharey=True)
ax1 = sns.histplot(x='hour', data=train[train["is_fraud"] == 0],
                   stat="density", bins=24, ax=ax1)
ax2 = sns.histplot(x='hour', data=train[train["is_fraud"] == 1],
                   stat="density", bins=24, ax=ax2, color="blue")
ax1.set_title("Normal")
ax2.set_title("Fraud")
ax1.set_xticks(np.arange(1, 24))
ax2.set_xticks(np.arange(1, 24))
# Out:
# c:\Users\zaid2\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\zaid2\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# [<matplotlib.axis.XTick at 0x1fab2248410>,
#  <matplotlib.axis.XTick at 0x1fa9f5e1c50>,
#  <matplotlib.axis.XTick at 0x1fa06085ed0>,
#  <matplotlib.axis.XTick at 0x1fa060ab490>,
#  <matplotlib.axis.XTick at 0x1fa060b5b10>,
#  <matplotlib.axis.XTick at 0x1fa0607ebd0>,
#  <matplotlib.axis.XTick at 0x1fa060bd050>,
#  <matplotlib.axis.XTick at 0x1fab1fdde50>,
#  <matplotlib.axis.XTick at 0x1fa060fb050>,
#  <matplotlib.axis.XTick at 0x1fa060fbc90>,
#  <matplotlib.axis.XTick at 0x1fa06103150>,
#  <matplotlib.axis.XTick at 0x1fa06103cd0>,
#  <matplotlib.axis.XTick at 0x1fa0610b210>,
#  <matplotlib.axis.XTick at 0x1fa0610ae90>,
#  <matplotlib.axis.XTick at 0x1fa0610d5d0>,
#  <matplotlib.axis.XTick at 0x1fa0610e150>,
#  <matplotlib.axis.XTick at 0x1fa06119490>,
#  <matplotlib.axis.XTick at 0x1fa0611b490>,
#  <matplotlib.axis.XTick at 0x1fa0611bc50>,
#  <matplotlib.axis.XTick at 0x1fa07481910>,
#  <matplotlib.axis.XTick at 0x1fa07482210>,
#  <matplotlib.axis.XTick at 0x1fa07484850>,
#  <matplotlib.axis.XTick at 0x1fa07487790>]

# %%
# Does the month has any impact
train['month'] = pd.to_datetime(train['trans_date_trans_time']).dt.month
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6), sharey=True)
ax1 = sns.histplot(x='month', data=train[train["is_fraud"] == 0],
                   stat="density", bins=12, ax=ax1)
ax2 = sns.histplot(x='month', data=train[train["is_fraud"] == 1],
                   stat="density", bins=12, ax=ax2, color="blue")
ax1.set_title("Normal")
ax2.set_title("Fraud")
ax1.set_xticks(np.arange(1, 13))
ax2.set_xticks(np.arange(1, 13))
# Out:
# c:\Users\zaid2\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\zaid2\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# [<matplotlib.axis.XTick at 0x1fa074cd790>,
#  <matplotlib.axis.XTick at 0x1fa074febd0>,
#  <matplotlib.axis.XTick at 0x1fa075778d0>,
#  <matplotlib.axis.XTick at 0x1fa0758ead0>,
#  <matplotlib.axis.XTick at 0x1fa0758f190>,
#  <matplotlib.axis.XTick at 0x1fa0758e210>,
#  <matplotlib.axis.XTick at 0x1fa0759bed0>,
#  <matplotlib.axis.XTick at 0x1fa0759c850>,
#  <matplotlib.axis.XTick at 0x1fa074ae3d0>,
#  <matplotlib.axis.XTick at 0x1fa074cf190>,
#  <matplotlib.axis.XTick at 0x1fa0757aad0>,
#  <matplotlib.axis.XTick at 0x1fa075b8a10>]

# %%
train.drop(columns=["merchant", "first", "last", "street",
           "unix_time", "trans_num"], inplace=True)

# %%
# "amt" category has very little spacing between small numbers and large spacing between high numbers.

p99 = train["amt"].quantile(0.99)
sns.kdeplot(x="amt", data=train[train["amt"] <= p99], fill=True)
# Out:
# c:\Users\zaid2\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='amt', ylabel='Density'>

# %%
# We are going to use non logarithm scaling
train["amt_log"] = np.log1p(train["amt"])
sns.kdeplot(train["amt_log"], fill=True)
# Out:
# c:\Users\zaid2\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='amt_log', ylabel='Density'>

# %%
def apply_woe(train, columns, target_col):
    woe = ce.WOEEncoder()

    for col in columns:
        X = train[col]
        y = train[target_col]

        new_col_name = f"{col}_WOE"
        train[new_col_name] = woe.fit_transform(X, y)

    return train


columns_to_encode = ["category", "state", "city", "job"]
target_column = "is_fraud"

train = apply_woe(train, columns_to_encode, target_column)

# %%
train.head(5)
# Out:
#   trans_date_trans_time            cc_num       category     amt gender  \
# 0   2019-01-01 00:00:18  2703186189652095       misc_net    4.97      F
# 1   2019-01-01 00:00:44      630423337322    grocery_pos  107.23      F
# 2   2019-01-01 00:00:51    38859492057661  entertainment  220.11      M
# 3   2019-01-01 00:01:16  3534093764340240  gas_transport   45.00      M
# 4   2019-01-01 00:03:06   375534208663984       misc_pos   41.96      M
#
#              city state    zip      lat      long  city_pop  \
# 0  Moravian Falls    NC  28654  36.0788  -81.1781      3495
# 1          Orient    WA  99160  48.8878 -118.2105       149
# 2      Malad City    ID  83252  42.1808 -112.2620      4154
# 3         Boulder    MT  59632  46.2306 -112.1138      1939
# 4        Doe Hill    VA  24433  38.4207  -79.4629        99
#
#                                  job         dob  merch_lat  merch_long  \
# 0          Psychologist, counselling  1988-03-09  36.011293  -82.048315
# 1  Special educational needs teacher  1978-06-21  49.159047 -118.186462
# 2        Nature conservation officer  1962-01-19  43.150704 -112.154481
# 3                    Patent attorney  1967-01-12  47.034331 -112.561071
# 4     Dance movement psychotherapist  1986-03-28  38.674999  -78.632459
#
#    is_fraud  age  hour  month   amt_log  category_WOE  state_WOE  city_WOE  \
# 0         0   36     0      1  1.786747      0.924914  -0.156457 -2.469513
# 1         0   46     0      1  4.684259      0.898799  -0.122657 -3.027790
# 2         0   62     0      1  5.398660     -0.847622  -0.988155 -1.076791
# 3         0   57     0      1  3.828641     -0.209382  -0.727015  1.746674
# 4         0   38     0      1  3.760269     -0.611091   0.162213 -2.464077
#
#     job_WOE
# 0 -1.080186
# 1 -0.904144
# 2  1.120434
# 3  0.361872
# 4 -2.464077

# %%
gender_mapping = {"F": 0, "M": 1}

train["gender_binary"] = train["gender"].map(gender_mapping)

# %% [markdown]
# **Frauds are more propitious to happen in credit cards with less use (new ones), and when it comes to normal transactions, it follows a normal distribution.**

# %%
X = train.drop(columns=["is_fraud"])
y = train["is_fraud"]

# %%
rus = RandomUnderSampler(sampling_strategy=0.1, random_state=23)
X_undersampled, y_undersampled = rus.fit_resample(X, y)

X_undersampled["random_feat_1"] = np.random.randint(
    0, 100, size=len(X_undersampled))
X_undersampled["random_feat_2"] = np.random.randint(
    0, 500, size=len(X_undersampled))

# %%
X_train = X_undersampled.drop(columns=["trans_date_trans_time",
                                       "city", "state", "category", "gender", "dob", "job", "cc_num", "amt"])

y_train = y_undersampled

# %%
X_train.head()
# Out:
#           zip      lat      long  city_pop  merch_lat  merch_long  age  hour  \
# 118515  77566  29.0393  -95.4401     28739  29.240616  -95.430963   25     5
# 598857  12460  42.4069  -74.1528       277  41.558414  -74.093286   53     7
# 59238   98304  46.7531 -121.9898       759  46.604923 -122.183106   68    18
# 710180  31042  32.8088  -83.1740      1841  33.088094  -84.140101   49     5
# 6204    99160  48.8878 -118.2105       149  48.078338 -119.143344   46    23
#
#         month   amt_log  category_WOE  state_WOE  city_WOE   job_WOE  \
# 118515      3  3.888345     -0.209382  -0.135704  0.138686  0.352429
# 598857      9  4.646120      0.898799   0.140597  0.204793  0.698244
# 59238       2  2.391511     -0.698428  -0.122657  0.774392  0.113063
# 710180     10  3.630456     -0.611091  -0.026475  0.002823 -0.231138
# 6204        1  1.423108      1.122029  -0.122657 -3.027790 -0.904144
#
#         gender_binary  random_feat_1  random_feat_2
# 118515              1             40            289
# 598857              1             71            255
# 59238               0             50            389
# 710180              1             80            451
# 6204                0             55            424

# %%
rf = RandomForestClassifier(random_state=23, max_depth=5)
feat_selector = BorutaPy(rf, n_estimators="auto", random_state=999)
result_boruta = feat_selector.fit(X_train.values, y_train)
accept = X_train.columns[feat_selector.support_].to_list()
irresolution = X_train.columns[feat_selector.support_weak_].to_list()

print("Features selected:")
list(accept)
# Out:
# Features selected:
# ['zip',
#  'lat',
#  'long',
#  'city_pop',
#  'merch_lat',
#  'merch_long',
#  'age',
#  'hour',
#  'month',
#  'amt_log',
#  'category_WOE',
#  'state_WOE',
#  'city_WOE',
#  'job_WOE',
#  'gender_binary']

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
importances = rf.feature_importances_

# %%
forest_importances = pd.Series(importances, index=X_train.columns)

fig, ax = plt.subplots(figsize=(12, 5))
forest_importances.sort_values(ascending=False).plot.bar(ax=ax)
ax.set_ylabel("Feature Importance")
fig.tight_layout()

# %%
X_train.drop(columns=["gender_binary", "state_WOE", "zip", "long", "lat",
                      "city_pop", "month",
                      "random_feat_1", "random_feat_2", "merch_long"], inplace=True)
